# %%
# do these steps before you run the code:
# 1. run before_preprocess.py before you run this code
# 2. if you are using pip: pip install scikit-image
#    if you are using conda: conda install -c conda-forge scikit-image
# 3. create a file in image call: clean_preprocess_png and miss_preprocess_png
#    tne image after preprocess steps will be stored in there

import csv
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
from skimage.feature import canny
from skimage.filters import sobel
from skimage.transform import hough_line, hough_line_peaks
from skimage.draw import polygon
from matplotlib import pylab as pylab

miss_table_path = "..\\..\\datasets\\table\\miss_metadata.csv"
clean_table_path = "..\\..\\datasets\\table\\clean_metadata_test.csv"
miss_png_path = "..\\..\\datasets\\image\\miss_png\\"
clean_png_path = "..\\..\\datasets\\image\\clean_png_test\\"
miss_preprocess_png = "..\\..\\datasets\\image\\miss_preprocess_png\\"
clean_preprocess_png = "..\\..\\datasets\\image\\clean_preprocess_png\\"

miss_ori = list(map(lambda x: x.split('/')[9], pd.read_csv(miss_table_path, dtype=str)['anon_dicom_path']))
miss_ori_pos = list(map(lambda x: x, pd.read_csv(miss_table_path, dtype=str)['ViewPosition']))
miss = zip(miss_ori, miss_ori_pos)
clean_ori = list(map(lambda x: x.split('/')[9], pd.read_csv(clean_table_path, dtype=str)['anon_dicom_path']))
clean_ori_pos = list(map(lambda x: x, pd.read_csv(clean_table_path, dtype=str)['ViewPosition']))
clean = zip(clean_ori, clean_ori_pos)

def bilateral_filter(ori_path):  
    ori_img = cv2.imread(ori_path, 0)
    # print(ori_path,'to', bil_path)
    if ori_img is not None:
        bil_img = cv2.bilateralFilter(ori_img, 9, 150, 150)
        return bil_img
    else:
        return False

def select_breast_area(bil_img):
    # binarization: use thresholding to create a binary mask
    th, img_binary = cv2.threshold(bil_img, 7, 255, cv2.THRESH_BINARY)
    # expand the border of white contours (dliate -> open)
    kernel = np.ones((21,21),np.uint8)
    img_opening = cv2.morphologyEx(img_binary, cv2.MORPH_OPEN, kernel)
    # deciding the breast area with binary mask
    img_masked = cv2.bitwise_and(bil_img,img_opening)
    return img_masked

def clahe(img):
    equ = cv2.equalizeHist(img)
    clahe = cv2.createCLAHE(clipLimit =3.0, tileGridSize=(4,4))
    cl_img = clahe.apply(img)
    ret, thresh3 = cv2.threshold(cl_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return cl_img

def apply_canny(image):
    # img = cv2.medianBlur(image, 9)                 # 模糊化，去除雜訊
    output = cv2.Canny(image, 10, 35) 
    return output

def get_hough_lines(canny_img):
    h, theta, d = hough_line(canny_img)
    lines = list()
    # print('\nAll hough lines')
    for _, angle, dist in zip(*hough_line_peaks(h, theta, d)):
        # print("Angle: {:.2f}, Dist: {:.2f}".format(np.degrees(angle), dist))
        x1 = 0
        y1 = (dist - x1 * np.cos(angle)) / np.sin(angle + 0.0001)
        x2 = canny_img.shape[1]
        y2 = (dist - x2 * np.cos(angle)) / np.sin(angle + 0.0001)
        lines.append({
            'dist': dist,
            'angle': np.degrees(angle),
            'point1': [x1, y1],
            'point2': [x2, y2]
        })
    
    return lines

def shortlist_lines(lines):
    MIN_ANGLE = 20
    MAX_ANGLE = 90
    MIN_DIST  = 100
    MAX_DIST  = 1300
    
    shortlisted_lines = [x for x in lines if 
                          (x['dist']>=MIN_DIST) &
                          (x['dist']<=MAX_DIST) &
                          (x['angle']>=MIN_ANGLE) &
                          (x['angle']<=MAX_ANGLE)
                        ]
    # print('\nShorlisted lines')
    # for i in shortlisted_lines:
    #     print("Angle: {:.2f}, Dist: {:.2f}".format(i['angle'], i['dist']))
        
    return shortlisted_lines

def remove_pectoral(shortlisted_lines):
    shortlisted_lines.sort(key = lambda x: x['dist'])
    # print(shortlisted_lines)
    pectoral_line = shortlisted_lines[0]
    d = pectoral_line['dist']
    theta = np.radians(pectoral_line['angle'])
    
    x_intercept = d/np.cos(theta)
    y_intercept = d/np.sin(theta)
    
    return polygon([0, 0, y_intercept], [0, x_intercept, 0])

def hough(image, cla_image):
    rows, cols = image.shape

    # Step 2: Contour detection using Canny filter
    img = cv2.medianBlur(image, 33)  
    canny_image = apply_canny(img)

    # Step 3: Linear aperture filtering
    filtered_image = cv2.filter2D(canny_image, -1, np.array([[0, 2, 0], [2, 2, 2], [0, 2, 0]]))

    # Step 4: Line detection using Hough Transform
    lines = get_hough_lines(filtered_image)
    shortlisted_lines = shortlist_lines(lines)
    
    # Step 5: Apply the Hough mask to the region of interest
    if len(shortlisted_lines) > 0:
        rr, cc = remove_pectoral(shortlisted_lines)
        # Create a boolean mask for the conditions
        mask = (rr < rows) & (cc < cols)
        # Set values to 0 where the conditions are met
        cla_image[rr[mask], cc[mask]] = 0
        return cla_image
    else:
        return cla_image

# test_pic = "../../datasets/image/clean_png/1.2.826.0.1.3680043.8.498.47732203502109542379863372984797251601.dcm.png"
# new_path = "../../datasets/image/clean_png/test5_clahe.png"

# bil_img = bilateral_filter(test_pic)
# masked_img = select_breast_area(bil_img)
# cl_img = clahe(masked_img)
# cv2.imwrite(new_path, cl_img)

#for name, pos in clean:
#    ori_path = clean_png_path+name+".png"
#    new_path = clean_preprocess_png+name+".png"
#    print('Preprocessing clean data...', name)
#    bil_img = bilateral_filter(ori_path)
#    if not isinstance(bil_img, np.ndarray):
#        print('Already remove')
#        continue
#    masked_img = select_breast_area(bil_img)
#    clahe_img = clahe(masked_img)
#    if pos == 'MLO' and name != '1.2.826.0.1.3680043.8.498.70762477675858797757470697309230496157.dcm':
#        rows, cols = clahe_img.shape
#        roi = clahe_img[:3 * rows//4, :cols//3]
#        hough_img = hough(roi, clahe_img)
#        cv2.imwrite(new_path, hough_img)
#        print('continue')
#    else:
#        cv2.imwrite(new_path, clahe_img)
#        print('continue')
#print('Clean Finish ...')

#for name, pos in miss:
#    ori_path = miss_png_path+name+".png"
#    new_path = miss_preprocess_png+name+".png"
#    print('Preprocessing miss data...', name)
#    bil_img = bilateral_filter(ori_path)
#    if not isinstance(bil_img, np.ndarray):
#        print('Already remove')
#        continue
#    masked_img = select_breast_area(bil_img)
#    clahe_img = clahe(masked_img)
#    if pos == 'MLO':
#        rows, cols = clahe_img.shape
#        roi = clahe_img[:2 * rows//3, :cols//3]
#        hough_img = hough(roi, clahe_img)
#        cv2.imwrite(new_path, hough_img)
#        print('continue')
#    else:
#        cv2.imwrite(new_path, clahe_img)
#        print('continue')
#print('All Finish !!!!!!!')

def preprocess_hugging(dicom):
    return
# Out:
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13280973993930913252605180204422965155.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.21419879400540352363681436133028226505.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.26423713590434578534969018531762460178.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.47732203502109542379863372984797251601.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.74062238417712591456906168298444025707.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.54899517756150043003148075684900651492.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.98642189091565722493589296817452112120.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.55833820638172105713248185193903285139.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.33553870725861110783382338904917069693.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.56946845697365358570075110722311589774.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.54459819801102153287674328113626733749.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.15798783315101091702270328020368327921.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.51678781962752148228405223475928093225.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.82524669012635031932282651609901990116.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.70762477675858797757470697309230496157.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.49658872064285048108439766618395178892.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11174991101797002704840887034114126428.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.48582419267361919716273656377262878666.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.44200725064894356531230494259413720957.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13133181512314652943748397996076757825.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11370671346738317852738959959734589586.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.91834313643384406867491483507147312722.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.58638613439840615946363890120806643922.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.69071597029523690507650697989983609866.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.77114801611717435574474344682743154761.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10780071173724584492039864570556878158.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12478153500034491718093909163768349211.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10698899305354230233959799961890085503.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.41876648074206030414365145218813196802.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.48568981462033909869781061129977438855.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11465240374311595083020602011209513509.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.59365153894825320159757011905804615704.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.64715893481260247908324311774228899976.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12272569886735569234087584945513283381.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.16317629948416014547949290738040365137.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.97604525402371893966284684177406342826.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.58876108386702437826368448243564916151.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.16259437723352054358066157226715657899.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.62946541356067552033604510925791729677.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.92765234028896816483455257585763786720.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.80808130306301753137901121453575587031.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.77920636268970535792636724633593336647.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.68978306237008211484115455297165562221.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.43144853700736848177811488124515956144.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.91042689790450638441322834323583767507.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.20524551377536773867380467497936228924.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12106225906111366323112609577363773410.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.69624639116442448377815289165585749813.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12831933061240733779364985044916536486.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.28458881887138156673288334418618645662.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.70663890616593615824152642750173103379.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.26825740383186227759107827869598110177.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10978511438314919654949396014108347460.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.18739581008825144223804067415427318934.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.29737572394469363245373141886045516295.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10000118454892828674141713285403927285.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.96887496307213764546157097518311861332.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.45613700355672382980391731981471857050.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.97055814690599252994687379658606848096.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.73433835766619000228576009087395226872.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.90805494562548724730635354983200873567.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10401972032039037911062361984601712765.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.70925138984543511420387818261782788808.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.21894601042442978516744242729619263475.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11436164204665390814995799372077870615.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.50981238125114956382665070583113717107.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10221252682857241805627930506693194238.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.25794939073484968717637625023767384244.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.53685641889613336958557997111096847632.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.27980873295450306118125789441834334835.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12303707282854471746182616092287040779.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11193360728971218809138745056777609355.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.55104938766280086093612546237920444050.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10587260598302591696972145016886532698.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.99886936630667879671345493081794735084.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.88104327679356400991545308512088414117.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.96942495962798021732446356217278642698.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.25283982197844949664220173084845491635.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.78586063503655513897330991411956716539.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11306837362195098846426684262060953929.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10904209073689606178290187176190379820.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22477803212205207339727942841522732138.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13027488440051037447851889081890863895.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12934020767159157632553749964185877384.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.71011186205832531412905971512355664206.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.39801203134045174586038069717628827451.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12480398282403345981947503102961627463.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22587093294455317787024263280040427021.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.99041524917011281372477576489748962245.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11271518711327945295430727290474072985.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.35112812406810801630673234875880457036.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.62466820363815498824394411192817846358.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.40582269092803727268200283746259354307.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.69221404896442107206232644412759922986.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.32309243116592353783567516518524000217.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.21442271224559557457689910981515614799.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13223002768866264531422838492648702345.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12395401845967596547836538147139180021.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.48104767213947361944394394787233354080.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11101942299125153894602436175293153279.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13174663057145065873244786397248542807.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13314435927114766110874477320808190825.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.84499587799907189828519404778249624305.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.66076187192737720891057905041122027629.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12964604078112137003771574662816270184.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.83732876763164730071957422525623967306.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.90073728417873104060694404592929974481.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.34199433266920404301037525491156832285.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11989153854280710833742026715660245102.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.74698060839013117851574099009479898252.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.92564073119049483292237203567211559108.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.87884220611232032396131176827780223390.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.74682005603038923438594265021267312650.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.61500938065528653796270782695790062052.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.49704046080319652550870690680512436452.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12894384164806040460552605205012113885.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.55899053520066780879535086099857731893.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.80465268525481726828505779495790536824.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12649792079852083832504167023738644392.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13326129793655542100113196988930753628.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.64742021361403077854789315369532960285.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10187449661768300870324275098959756338.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12551788717412858580562414500701243952.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.84944964980691455305047781008045799448.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12818110917574112765510051197810412872.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.14103424753761290917215289888493574098.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.71169088319219386923988894426702526399.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.79518391913059295589766265746488589536.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.93532750116297706275245757364690836947.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.30338829045346979386533302301494082031.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.44789778921113879158683991283803920845.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.79005785471976393015693846942085253905.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.26658044448699008607853355270039870626.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.45362789551519483453259977235188760878.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.33190744890785341673411425358933914137.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11161880597451989019710851841470612339.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.37911828441169126375633302002710533212.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.94738406847183735111711195956463472271.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.20890035544876265706441736722532831313.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.48297995259765879238297526319393037885.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.14412589878007252555313559950574895447.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.68913690833137210741638112668742473670.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10733719308286043535010217777259727082.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11257746696922799061070123457016506308.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.61903272093142527080977347094091854243.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.91519226044358941086386918134484667911.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.59716416242108137010595736604987124463.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12958777985500091029197306371750374301.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.80366193675687115238139564637658752453.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11700089120238810412232821488885356875.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.24469938838169894979247687089859000763.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.60714757253054194879969957396574066168.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.97534254146601338478118693740556084398.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.42320200705395499550004882422253426296.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.32257290341342712029215380684661167972.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11582862578203762523577286621687801663.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11641266723892077496086208887869875654.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.91014836381292754815973193308843646852.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13917254660160308882599055800002123003.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.18301960482059943332896340368608496495.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.43483645616407608305057910729180812456.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11716074936795611149567439716319568053.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.52258937656257312144172789673547496103.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.36759096240215101210992832425261858204.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.57435526728709223837028871717832538742.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.19190918592194441550438226494970833696.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.42836128591454666028889356082493171400.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.62634194794419117548015972185897414882.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.91682304984475123995761591700804375073.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11449214959488141027739004164960499582.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.54647702865324985995752806974234505821.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.76342449567608449997086107925341606521.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.89718073026203160007520198970809412202.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.98893060177974900541828794983635257536.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.26475759461159443339543679018594691975.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22003360247498370058204664520075899710.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.86234873155858088104015228571389835430.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.18175985059057747065781557258286872431.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.86304405326496575152250632341340774999.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.73421222872903305988888866464098365107.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.52876746313797026845634060707579961177.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.88727706115014951471872433172452148899.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10003717510451391223009508080002467919.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10898363002233205231915427324895339402.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.38239154272051203190793742421941900612.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10739975411346167434760260163746387829.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22433857724588345741276494905007410641.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12892369466742581994917591809831469388.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12073833979451037078150255398540747132.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.83089167330770857237424390115954343792.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.59308810907317670397272184361863123827.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11777634075681437972418716982100262052.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.86497510960203109016891233057491109443.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.98378139704809777357488595120042186628.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12431699271088306094914414884374800448.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.23214464484805778767947446536936103849.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.18505171692131206582126823931702558680.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.56272893208826343935324718232478583042.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.33970098036611647533045023824115885653.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.79781925888084547583218246783795851860.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.90511253363330017293204370635498280660.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.37709288767831612371923275198663555902.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10157527470275083459759519145647603441.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.41498462318588454426425299345559736285.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13104782606586579349775548116165376805.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11315688266457678615654417974764640277.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.68247346281134490377638857369249602209.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11924598845443096630153063450329607158.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.96060307990734495510053334382795173651.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.44363420548100837611373167748278483595.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.16668855794075673309225874537693328915.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.68332783447984128972325702523525299085.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.43968575115695251162814676294999166943.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.16682636089149444538223075502791368534.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.38027995641845468717269908208761777844.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.44900463735959432603012364423642077207.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.60255669657777486279802350252909887771.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.51906754922499527793824147450878998176.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.75911745153209372152471504067750503726.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.87213567591860126026390017555441891759.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.35243124038639653326409267615926837320.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.25021604009056415302004954307855909621.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12644536506190227453542185508780327585.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12569322550904202251831813575002092476.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22386990066707062029923060012563980011.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13390848337923363562050224823713249212.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12318194965126148724668869981938917523.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.77682116603268729163950327617176214750.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.75983714377888116649634094792966609974.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.75421613991135456516906967925554324595.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.89294675067014737413932961816902633129.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.82276011832246839217898535523318555722.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11898361951148251645529130688375480365.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.13891295687382430418013731196039933027.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12788177810493863322755853591705867072.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12443956778957818611311940534916189016.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.32664205305461867210621104903578147473.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12445511937933095598352531569546592357.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.36057881798565919366292679762265885542.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.40673145987930678719301331503168428656.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.40392950220389744261377831143289676863.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.28469931733182082640785087181325457312.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.59877644418527909236698645332612162287.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12881031680755571511975231586509286016.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.58551691841558227495559254032643130081.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11919235314223770796056649660584187117.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.73207258762099253611670992101253930196.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12698910912950184318825331985693307520.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.29152089933760070593678534982527285186.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.38954612544141917054352345500869133589.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.99790429312794699110262333812775347002.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.44885168727079808376739930989145223806.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.34466093929916909307152267712155883688.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.94150265544431400435659375418496645784.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12646909366755539923536927505698300748.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.67324175167686648928076347970393115339.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.34514314965818827023861069987574756111.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.57433836138933870376259919849956690226.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.20284495326103918698247628225339228836.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11704553615273553240356768337539910615.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.31971486038572847421546921805020252334.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.44866349157177742187135243083668154738.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.87687850192114241688849566056269426951.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22844998970594924031726946058192884701.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.55047912079675747599824284644540388914.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.32999959567664237407768798808510740483.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.83360387236523273821482514373508749723.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.98042352392373175215127194942644092789.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.33592088368317461968375730159254049501.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.73462827319702847892843279494682664316.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10449603616622428040769568965691681314.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.40061795118437916249195283892852267741.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12387512298239299014691147378254591727.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.18844427705682086203166246193758261125.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.20372989617936790462739904624042788283.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.21816516526013680390392445954812868153.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.30587731581279557297670132851908819946.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.20484428443264121417395607415186340409.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.79738918212606865239239250637497458043.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.73721139443329888973394129141060301005.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10294920545054525743025929094974624016.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.14214185776323165451765211881410112461.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.46679668062482152185892726626332423692.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.90125947309585130312312283206576728048.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10578470888337456400528059663670396834.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10774414655901844896849026294002160095.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.31075521723523325205488013491495721299.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.80691230394153754753971116977489620386.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.23903715827851825223645988505611997252.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.77243929625656278595214711164093466241.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.25570310094403419885866741911222950222.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.43282867711475742236089817484539121913.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.48890732309166041367790656930710640518.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.30098264270538512951274946902433982557.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.42766017888067362354886678073738945105.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.30107660556820350394250293614823192224.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.95789302065376934059710741575046957862.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.66562354397657398353674272051384197589.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.89249635684787307155972648565879663098.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.93619575101759456919642944161253529249.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.77458335285982079996236357994700373710.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.62060331362551335394960064029848204074.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.22147937688178307689251748765661595154.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.33779204386614789978612560915618858715.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.73618677755764750662982256102143041227.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.26123438967329213632108209920546167232.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.45527019207297467754966448927060433957.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.77671330093438316287970628657579230497.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.76223921581754826509641731930450202994.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.70888763585842923390783208094855804135.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.57921024425583203693373348226487549285.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11915158718420733794355878529431459504.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10311652439931836523066929486881470878.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.66146042827324069321772690438469303593.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.93842544332324412544367810610686873027.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.14944000259122346120465234054852212703.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12007350540290248914649837357064742579.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.31518898350589848564147137332071633255.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.10653222866827040116027844615227141257.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.18532322029108157109573992042273126510.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11802957416114654689122595166930114333.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.66465885096732080364241581561587956171.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12863199436905679220607448647880558349.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.35789251971746096270753100631985151285.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11861740694645147344701075252211043307.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.12648981321633130233316704936418845188.dcm
# continue
# Preprocessing clean data... 1.2.826.0.1.3680043.8.498.11530621629254921452007294649639337329.dcm
# continue
# Clean Finish ...
